# %% [markdown]
# ## Random numbers in python

# %%
import random
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
x=random.random()
x
# Out:
# 0.6648706158810691

# %%
x= random.random() # Generate a random number between 0 and 1
values = [random.random() for i in range(1000)]
# values
plt.plot(values)

# %%
x1=random.uniform(0,10)
values = [random.uniform(0,10) for i in range(1000)]
plt.plot(values)

# %%
x1 = random.expovariate(1) # Generate a random number using exponential distribution
values1 = [ random.expovariate(1) for i in range(1000) ]
plt.plot(values1)

# %%
x2= random.gauss(0,1) # Generate a random number using Gaussian distribution
values2 = [ random.gauss(0,1) for i in range(1000) ]
plt.plot(values2)

# %%
x=random.random() # Generate a random number between 0 and 1
y=random.uniform(1,10) # Generate a random number between 1 and 10
z=random.randint(1,10)  # Generate a random integer between 1 and 10
print(x,y,z)
# Out:
# 0.6651863939573956 3.550929255783184 2

# %%
coin_toss = [random.randint(0,1) for i in range(1000)]
sum(coin_toss)/len(coin_toss)
# Out:
# 0.478

# %%
# random choice from list
greetings = ['hello', 'hi', 'hey', 'hola', 'bonjour']
random.choice(greetings) # random choice from list
random.choices(greetings, k=7) # random choice from list with k=3
# Out:
# 'bonjour'
# ['hi', 'hi', 'hello', 'bonjour', 'hi', 'hi', 'hey']

# %%
# weighted random choice from list
colors = ["red", "green", "blue", "yellow", "orange", "purple"]
results = random.choices(colors, weights=[5.2, 0.1, 0.3, 0.2, 0.2, 0.2], k=10)
results
# Out:
# ['red', 'red', 'orange', 'yellow', 'purple', 'red', 'red', 'red', 'red', 'red']

# %%
# Shuffle a list
deck = list(range(1,53))
random.shuffle(deck)
print(deck)
# Out:
# [18, 29, 45, 52, 13, 41, 28, 36, 37, 12, 38, 50, 8, 14, 21, 10, 2, 20, 24, 43, 6, 32, 7, 48, 26, 33, 22, 39, 9, 11, 23, 15, 1, 51, 49, 19, 27, 5, 35, 47, 4, 46, 40, 16, 3, 44, 25, 31, 34, 17, 30, 42]

# %%
# randome sample from list
sample = random.sample(deck, k=5)
print(sample)
# Out:
# [36, 13, 32, 18, 10]

# %%
# Generating fake data 
first_names = ["Alice", "Bob", "Cathy", "Dan", "Ed", "Frank", "George"]
last_names = ["Smith", "Jones", "Brown", "Davis", "Garcia", "Miller"]

cities = ["New York City", "Los Angeles", "Chicago", "Houston", "Phoenix", "Philadelphia", "San Antonio", "San Diego", "Dallas", "San Jose"]

states = ["New York", "California", "Illinois", "Texas", "Arizona", "Florida", "Pennsylvania", "California", "Illinois", "Texas"]

data = []
for i in range(10):
    first = random.choice(first_names)
    last = random.choice(last_names)
    
    phone = f"{random.randint(100,999)}-{random.randint(100,999)}-{random.randint(1000,9999)}"
    
    street = random.randint(100,999)
    city = random.choice(cities)
    state = random.choice(states)
    zipcode = random.randint(10000, 99999)
    
    address = f"{street} {city} {state} {zipcode}"
    
    email = first.lower() + "." + last.lower() + "@gmail.com"
    print(f"{first} {last} {phone} {address} {email}\n")
    data.append([first, last, phone, address, email])
# Out:
# Bob Smith 717-707-2457 917 Los Angeles Illinois 33012 bob.smith@gmail.com
#
# Cathy Brown 513-444-5691 898 San Antonio Texas 75185 cathy.brown@gmail.com
#
# Dan Smith 427-626-7694 590 Houston Pennsylvania 27287 dan.smith@gmail.com
#
# Bob Garcia 935-501-9325 948 Philadelphia Texas 88547 bob.garcia@gmail.com
#
# Bob Smith 584-448-2258 975 San Jose Illinois 97995 bob.smith@gmail.com
#
# Cathy Brown 384-853-9265 606 Los Angeles Texas 54917 cathy.brown@gmail.com
#
# Alice Davis 950-232-9493 238 Dallas Texas 26838 alice.davis@gmail.com
#
# Cathy Garcia 476-122-4029 500 San Antonio Illinois 16561 cathy.garcia@gmail.com
#
# Ed Smith 188-435-8648 814 San Diego Illinois 35281 ed.smith@gmail.com
#
# Alice Brown 867-446-9814 999 San Jose New York 79284 alice.brown@gmail.com

# %%
data
# Out:
# [['Bob',
#   'Smith',
#   '717-707-2457',
#   '917 Los Angeles Illinois 33012',
#   'bob.smith@gmail.com'],
#  ['Cathy',
#   'Brown',
#   '513-444-5691',
#   '898 San Antonio Texas 75185',
#   'cathy.brown@gmail.com'],
#  ['Dan',
#   'Smith',
#   '427-626-7694',
#   '590 Houston Pennsylvania 27287',
#   'dan.smith@gmail.com'],
#  ['Bob',
#   'Garcia',
#   '935-501-9325',
#   '948 Philadelphia Texas 88547',
#   'bob.garcia@gmail.com'],
#  ['Bob',
#   'Smith',
#   '584-448-2258',
#   '975 San Jose Illinois 97995',
#   'bob.smith@gmail.com'],
#  ['Cathy',
#   'Brown',
#   '384-853-9265',
#   '606 Los Angeles Texas 54917',
#   'cathy.brown@gmail.com'],
#  ['Alice',
#   'Davis',
#   '950-232-9493',
#   '238 Dallas Texas 26838',
#   'alice.davis@gmail.com'],
#  ['Cathy',
#   'Garcia',
#   '476-122-4029',
#   '500 San Antonio Illinois 16561',
#   'cathy.garcia@gmail.com'],
#  ['Ed',
#   'Smith',
#   '188-435-8648',
#   '814 San Diego Illinois 35281',
#   'ed.smith@gmail.com'],
#  ['Alice',
# ...
